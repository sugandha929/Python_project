# %%
import pandas as pd

# %%
import matplotlib.pyplot as mp

# %%
a=pd.read_csv('2012-sat-results.csv', index_col='DBN')

# %%
a.head()
# Out:
#                                           SCHOOL NAME  Num of SAT Test Takers  \
# DBN
# 01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES                      29
# 01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL                      91
# 01M450                     EAST SIDE COMMUNITY SCHOOL                      70
# 01M458                      FORSYTH SATELLITE ACADEMY                       7
# 01M509                        MARTA VALLE HIGH SCHOOL                      44
#
#         SAT Critical Reading Avg. Score  SAT Math Avg. Score  \
# DBN
# 01M292                              355                  404
# 01M448                              383                  423
# 01M450                              377                  402
# 01M458                              414                  401
# 01M509                              390                  433
#
#         SAT Writing Avg. Score
# DBN
# 01M292                     363
# 01M448                     366
# ...

# %%
a['Total Avg. SAT Score']=a['SAT Critical Reading Avg. Score']+a['SAT Math Avg. Score']+a['SAT Writing Avg. Score']

# %%
a.head()
# Out:
#                                           SCHOOL NAME  Num of SAT Test Takers  \
# DBN
# 01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES                      29
# 01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL                      91
# 01M450                     EAST SIDE COMMUNITY SCHOOL                      70
# 01M458                      FORSYTH SATELLITE ACADEMY                       7
# 01M509                        MARTA VALLE HIGH SCHOOL                      44
#
#         SAT Critical Reading Avg. Score  SAT Math Avg. Score  \
# DBN
# 01M292                              355                  404
# 01M448                              383                  423
# 01M450                              377                  402
# 01M458                              414                  401
# 01M509                              390                  433
#
#         SAT Writing Avg. Score  Total Avg. SAT Score
# DBN
# 01M292                     363                  1122
# ...

# %%
a['Num of SAT Test Takers'].astype(int)
a['SCHOOL NAME'].astype(str)
a.index.astype(str)
a['SAT Critical Reading Avg. Score'].astype(int)
a['SAT Math Avg. Score'].astype(int)
a['SAT Writing Avg. Score'].astype(int)
# Out:
# DBN
# 01M292    363
# 01M448    366
# 01M450    370
# 01M458    359
# 01M509    384
# 01M515    316
# 01M539    525
# 01M650    411
# 01M696    628
# 02M047    387
# 02M288    392
# 02M294    378
# 02M296    362
# 02M298    432
# 02M300    416
# 02M303    340
# 02M305    385
# 02M308    405
# 02M313    390
# 02M316    384
# 02M374    394
# 02M376    479
# 02M394    357
# 02M400    461
# 02M407    467
# 02M408    523
# 02M411    518
# 02M412    550
# 02M413    515
# 02M414    459
#          ...
# 30Q301    405
# 30Q445    412
# 30Q450    395
# 30Q501    494
# 30Q502    398
# 30Q555    329
# 30Q575    491
# 30Q580    544
# 31R047    450
# 31R064    385
# 31R080    466
# 31R440    416
# 31R445    417
# 31R450    429
# 31R455    470
# 31R460    459
# 31R470    414
# 31R600    397
# 31R605    636
# 31R607    370
# 32K403    352
# 32K545    361
# 32K549    334
# 32K552    354
# 32K554    422
# 32K556    350
# 32K564    358
# 75Q811    433
# 79Q950    426
# 79X490    360
# ...

# %%
a.dtypes
# Out:
# SCHOOL NAME                        object
# Num of SAT Test Takers              int64
# SAT Critical Reading Avg. Score     int64
# SAT Math Avg. Score                 int64
# SAT Writing Avg. Score              int64
# dtype: object

# %%
a['SAT Critical Reading Avg. Score'].plot( color='red')
a['SAT Math Avg. Score'].plot(figsize=(20,20), color='black')
a['SAT Writing Avg. Score'].plot(figsize=(20,20), color='green')

# %%
a['Num of SAT Test Takers'].plot(figsize=(20,10), color='blue')
a['Total Avg. SAT Score'].plot(figsize=(20,10), color='grey')

# %%
a['Num of SAT Test Takers'].plot(figsize=(20,10), color='blue')
a['SAT Math Avg. Score'].plot(figsize=(20,10), color='grey')

# %%
a['Num of SAT Test Takers'].plot(figsize=(20,10), color='blue')
a['SAT Critical Reading Avg. Score'].plot(figsize=(20,10), color='orange')

# %%
a['Num of SAT Test Takers'].plot(figsize=(20,10), color='blue')
a['SAT Writing Avg. Score'].plot(figsize=(20,10), color='green')

# %% [markdown]
# - Generally as number of test takers increases the total and individual avg. scores increase, with a few exceptions.
# - Math Has the highest score avg.
# - Critical Reading has the lowest score avg.

# %% [markdown]
# ### Top scorers

# %%
a[(a['SAT Math Avg. Score']>600) & (a['SAT Writing Avg. Score']>600) & (a['SAT Critical Reading Avg. Score']>600) ]['SCHOOL NAME']
# Out:
# DBN
# 01M696                       BARD HIGH SCHOOL EARLY COLLEGE
# 02M475                               STUYVESANT HIGH SCHOOL
# 10X445                         BRONX HIGH SCHOOL OF SCIENCE
# 10X696    HIGH SCHOOL OF AMERICAN STUDIES AT LEHMAN COLLEGE
# 25Q525                          TOWNSEND HARRIS HIGH SCHOOL
# 31R605                  STATEN ISLAND TECHNICAL HIGH SCHOOL
# Name: SCHOOL NAME, dtype: object

# %%
a[(a['Total Avg. SAT Score']>1800)]['SCHOOL NAME']
# Out:
# DBN
# 01M696                       BARD HIGH SCHOOL EARLY COLLEGE
# 02M475                               STUYVESANT HIGH SCHOOL
# 05M692    HIGH SCHOOL FOR MATHEMATICS, SCIENCE AND ENGIN...
# 10X445                         BRONX HIGH SCHOOL OF SCIENCE
# 10X696    HIGH SCHOOL OF AMERICAN STUDIES AT LEHMAN COLLEGE
# 13K430                       BROOKLYN TECHNICAL HIGH SCHOOL
# 25Q525                          TOWNSEND HARRIS HIGH SCHOOL
# 28Q687    QUEENS HIGH SCHOOL FOR THE SCIENCES AT YORK CO...
# 31R605                  STATEN ISLAND TECHNICAL HIGH SCHOOL
# Name: SCHOOL NAME, dtype: object

# %% [markdown]
# - There are more schools that have a higher Total Avg. Score than schools having a high svg. scor in all three areas.

# %% [markdown]
# ### Lowest Scorers

# %%
a.sort_values(['Total Avg. SAT Score'])['SCHOOL NAME'][:10]
# Out:
# DBN
# 19K583                        MULTICULTURAL HIGH SCHOOL
# 17K524    INTERNATIONAL HIGH SCHOOL AT PROSPECT HEIGHTS
# 10X342            INTERNATIONAL SCHOOL FOR LIBERAL ARTS
# 12X550                    HIGH SCHOOL OF WORLD CULTURES
# 07X334              INTERNATIONAL COMMUNITY HIGH SCHOOL
# 09X365              ACADEMY FOR LANGUAGE AND TECHNOLOGY
# 24Q296           PAN AMERICAN INTERNATIONAL HIGH SCHOOL
# 10X268            KINGSBRIDGE INTERNATIONAL HIGH SCHOOL
# 18K563                       IT TAKES A VILLAGE ACADEMY
# 09X403                  BRONX INTERNATIONAL HIGH SCHOOL
# Name: SCHOOL NAME, dtype: object

# %% [markdown]
# #### Math

# %%
a.sort_values(['SAT Math Avg. Score'])['SCHOOL NAME'][:10]
# Out:
# DBN
# 09X403           BRONX INTERNATIONAL HIGH SCHOOL
# 09X543          HIGH SCHOOL FOR VIOLIN AND DANCE
# 32K564            BUSHWICK COMMUNITY HIGH SCHOOL
# 05M285            HARLEM RENAISSANCE HIGH SCHOOL
# 18K563                IT TAKES A VILLAGE ACADEMY
# 19K583                 MULTICULTURAL HIGH SCHOOL
# 12X550             HIGH SCHOOL OF WORLD CULTURES
# 24Q296    PAN AMERICAN INTERNATIONAL HIGH SCHOOL
# 07X334       INTERNATIONAL COMMUNITY HIGH SCHOOL
# 10X342     INTERNATIONAL SCHOOL FOR LIBERAL ARTS
# Name: SCHOOL NAME, dtype: object

# %% [markdown]
# #### Writing

# %%
a.sort_values(['SAT Writing Avg. Score'])['SCHOOL NAME'][:10]
# Out:
# DBN
# 19K583                           MULTICULTURAL HIGH SCHOOL
# 17K524       INTERNATIONAL HIGH SCHOOL AT PROSPECT HEIGHTS
# 09X365                 ACADEMY FOR LANGUAGE AND TECHNOLOGY
# 12X388    PAN AMERICAN INTERNATIONAL HIGH SCHOOL AT MONROE
# 15K520                                 PACIFIC HIGH SCHOOL
# 10X342               INTERNATIONAL SCHOOL FOR LIBERAL ARTS
# 10X268               KINGSBRIDGE INTERNATIONAL HIGH SCHOOL
# 07X334                 INTERNATIONAL COMMUNITY HIGH SCHOOL
# 23K646                ASPIRATIONS DIPLOMA PLUS HIGH SCHOOL
# 24Q296              PAN AMERICAN INTERNATIONAL HIGH SCHOOL
# Name: SCHOOL NAME, dtype: object

# %% [markdown]
# #### Critical Reading

# %%
a.sort_values(['SAT Critical Reading Avg. Score'])['SCHOOL NAME'][:10]
# Out:
# DBN
# 09X403           BRONX INTERNATIONAL HIGH SCHOOL
# 09X543          HIGH SCHOOL FOR VIOLIN AND DANCE
# 32K564            BUSHWICK COMMUNITY HIGH SCHOOL
# 05M285            HARLEM RENAISSANCE HIGH SCHOOL
# 18K563                IT TAKES A VILLAGE ACADEMY
# 19K583                 MULTICULTURAL HIGH SCHOOL
# 12X550             HIGH SCHOOL OF WORLD CULTURES
# 24Q296    PAN AMERICAN INTERNATIONAL HIGH SCHOOL
# 07X334       INTERNATIONAL COMMUNITY HIGH SCHOOL
# 10X342     INTERNATIONAL SCHOOL FOR LIBERAL ARTS
# Name: SCHOOL NAME, dtype: object

# %% [markdown]
# ### Schools with maximum number of test takers

# %%
maximum=a.sort_values(['Num of SAT Test Takers'], ascending=False)

# %%
maximum[maximum.columns[:2]][:10]
# Out:
#                             SCHOOL NAME  Num of SAT Test Takers
# DBN
# 13K430   BROOKLYN TECHNICAL HIGH SCHOOL                    1277
# 26Q430        FRANCIS LEWIS HIGH SCHOOL                     934
# 26Q415  BENJAMIN N. CARDOZO HIGH SCHOOL                     888
# 02M475           STUYVESANT HIGH SCHOOL                     832
# 22K405              MIDWOOD HIGH SCHOOL                     824
# 31R455          TOTTENVILLE HIGH SCHOOL                     807
# 28Q440         FOREST HILLS HIGH SCHOOL                     762
# 10X445     BRONX HIGH SCHOOL OF SCIENCE                     731
# 21K525     EDWARD R. MURROW HIGH SCHOOL                     727
# 26Q495              BAYSIDE HIGH SCHOOL                     708

# %% [markdown]
# ### Schools with minimum number of test takers

# %%
minimum=a.sort_values('Num of SAT Test Takers')

# %%
minimum[minimum.columns[:2]][:10]
# Out:
#                                          SCHOOL NAME  Num of SAT Test Takers
# DBN
# 28Q338  QUEENS SATELLITE HIGH SCHOOL FOR OPPORTUNITY                       6
# 08X408                        HERBERT H. LEHMAN YABC                       6
# 23K646          ASPIRATIONS DIPLOMA PLUS HIGH SCHOOL                       7
# 25Q792            NORTH QUEENS COMMUNITY HIGH SCHOOL                       7
# 17K489            W.E.B. DUBOIS ACADEMIC HIGH SCHOOL                       7
# 18K635                               OLYMPUS ACADEMY                       7
# 01M458                     FORSYTH SATELLITE ACADEMY                       7
# 06M457                        GEORGE WASHINGTON YABC                       7
# 79Q950                           GED PLUS s CITYWIDE                       8
# 13K553                  BROOKLYN ACADEMY HIGH SCHOOL                       8

# %%
c=list(maximum['SCHOOL NAME'][:10])

# %%
c
# Out:
# ['BROOKLYN TECHNICAL HIGH SCHOOL',
#  'FRANCIS LEWIS HIGH SCHOOL',
#  'BENJAMIN N. CARDOZO HIGH SCHOOL',
#  'STUYVESANT HIGH SCHOOL',
#  'MIDWOOD HIGH SCHOOL',
#  'TOTTENVILLE HIGH SCHOOL',
#  'FOREST HILLS HIGH SCHOOL',
#  'BRONX HIGH SCHOOL OF SCIENCE',
#  'EDWARD R. MURROW HIGH SCHOOL',
#  'BAYSIDE HIGH SCHOOL']

# %%
d=list(a[(a['Total Avg. SAT Score']>1800)]["SCHOOL NAME"])
e=list(a[(a['SAT Math Avg. Score']>600) & (a['SAT Writing Avg. Score']>600) & (a['SAT Critical Reading Avg. Score']>600) ]['SCHOOL NAME'])

# %%
d
# Out:
# ['BARD HIGH SCHOOL EARLY COLLEGE',
#  'STUYVESANT HIGH SCHOOL',
#  'HIGH SCHOOL FOR MATHEMATICS, SCIENCE AND ENGINEERING AT CITY COLLEGE',
#  'BRONX HIGH SCHOOL OF SCIENCE',
#  'HIGH SCHOOL OF AMERICAN STUDIES AT LEHMAN COLLEGE',
#  'BROOKLYN TECHNICAL HIGH SCHOOL',
#  'TOWNSEND HARRIS HIGH SCHOOL',
#  'QUEENS HIGH SCHOOL FOR THE SCIENCES AT YORK COLLEGE',
#  'STATEN ISLAND TECHNICAL HIGH SCHOOL']

# %% [markdown]
# ### Schools with maximum number of test Takers and highest total avg. scores.

# %%
print(set(c).intersection(d))
# Out:
# {'BRONX HIGH SCHOOL OF SCIENCE', 'STUYVESANT HIGH SCHOOL', 'BROOKLYN TECHNICAL HIGH SCHOOL'}

# %% [markdown]
# ### Schools with maximum number of test Takers and highest individual avg. scores.

# %%
print(set(c).intersection(e))
# Out:
# {'BRONX HIGH SCHOOL OF SCIENCE', 'STUYVESANT HIGH SCHOOL'}

# %% [markdown]
# ### Schools with highest individual avg. scores and highest total avg. scores.

# %%
print(set(e).intersection(d))
# Out:
# {'BRONX HIGH SCHOOL OF SCIENCE', 'STUYVESANT HIGH SCHOOL', 'TOWNSEND HARRIS HIGH SCHOOL', 'STATEN ISLAND TECHNICAL HIGH SCHOOL', 'HIGH SCHOOL OF AMERICAN STUDIES AT LEHMAN COLLEGE', 'BARD HIGH SCHOOL EARLY COLLEGE'}
